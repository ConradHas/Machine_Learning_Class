# %%
# scikit-learn pereptron and adaline implementations
from sklearn.linear_model import Perceptron as SklearnPerceptron
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

# %%
#import df from csv
df = pd.read_csv("C:/Users/conra/OneDrive/Desktop/Machine Learning/Project 1/project_adult(1).csv")
df_test = pd.read_csv("C:/Users/conra/OneDrive/Desktop/Machine Learning/Project 1/project_validation_inputs(1).csv")

# %%
# Assumption:  This code assumes you have already clean, processed, and split a data set.

#Input Data Required:
#X_train = cleaned, processed input data for training prediction models
#X_train =  all colums except last column
X_train = df.iloc[:, :-1].values
#y_train = response variable associated with X_train; truth values
#y_train =  last column
y_train = df.iloc[:, -1].values
#X_test = cleaned, processed input data for testing prediction model created on training dataset
#X_test =  all columns
X_test = df_test.iloc[:, :].values
#y_test = response variable associated with X_test; truth values. the model will write its predictions to compare against these truth values
y_test = []

#Note: Current order of rows ensure y_train = X_train and y_test = X_test, but if you sort and remove rows this association changes.
X_train
# Out:
# array([[0, 39, 'State-gov', ..., 0, 40, 'United-States'],
#        [1, 50, 'Self-emp-not-inc', ..., 0, 13, 'United-States'],
#        [2, 38, 'Private', ..., 0, 40, 'United-States'],
#        ...,
#        [32555, 22, 'Private', ..., 0, 40, 'United-States'],
#        [32557, 40, 'Private', ..., 0, 40, 'United-States'],
#        [32559, 22, 'Private', ..., 0, 20, 'United-States']],
#       shape=(26048, 15), dtype=object)

# %%
# Scikit-learn Perceptron
sk_ppn = SklearnPerceptron(eta0=0.1, max_iter=15, random_state=42)
sk_ppn.fit(X_train, y_train)
sk_y_pred_ppn = sk_ppn.predict(X_test)
print(f"Scikit-learn Perceptron accuracy: {accuracy_score(y_test, sk_y_pred_ppn):.4f}")
# Scikit-learn Adaline (using SGDClassifier with 'log_loss' is closer, but 'perceptron' is available)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Scikit-learn Perceptron
#       2 sk_ppn = SklearnPerceptron(eta0=0.1, max_iter=15, random_state=42)
# ----> 3 sk_ppn.fit(X_train, y_train)
#       4 sk_y_pred_ppn = sk_ppn.predict(X_test)
#       5 print(f"Scikit-learn Perceptron accuracy: {accuracy_score(y_test, sk_y_pred_ppn):.4f}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_stochastic_gradient.py:920, in BaseSGDClassifier.fit(self, X, y, coef_init, intercept_init, sample_weight)
#     891 """Fit linear model with Stochastic Gradient Descent.
#     892
#     893 Parameters
#    (...)    916     Returns an instance of self.
#     917 """
#     918 self._more_validate_params()
# --> 920 return self._fit(
#     921     X,
#     922     y,
#     923     alpha=self.alpha,
#     924     C=1.0,
#     925     loss=self.loss,
#     926     learning_rate=self.learning_rate,
#     927     coef_init=coef_init,
#     928     intercept_init=intercept_init,
#     929     sample_weight=sample_weight,
#     930 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_stochastic_gradient.py:707, in BaseSGDClassifier._fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     704 # Clear iteration count for multiple call to fit.
#     705 self.t_ = 1.0
# --> 707 self._partial_fit(
#     708     X,
#     709     y,
#     710     alpha,
#     711     C,
#     712     loss,
#     713     learning_rate,
#     714     self.max_iter,
#     715     classes,
#     716     sample_weight,
#     717     coef_init,
#     718     intercept_init,
#     719 )
#     721 if (
#     722     self.tol is not None
#     723     and self.tol > -np.inf
#     724     and self.n_iter_ == self.max_iter
#     725 ):
#     726     warnings.warn(
#     727         (
#     728             "Maximum number of iteration reached before "
#    (...)    732         ConvergenceWarning,
#     733     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_stochastic_gradient.py:598, in BaseSGDClassifier._partial_fit(self, X, y, alpha, C, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     583 def _partial_fit(
#     584     self,
#     585     X,
#    (...)    595     intercept_init,
#     596 ):
#     597     first_call = not hasattr(self, "classes_")
# --> 598     X, y = validate_data(
#     599         self,
#     600         X,
#     601         y,
#     602         accept_sparse="csr",
#     603         dtype=[np.float64, np.float32],
#     604         order="C",
#     605         accept_large_sparse=False,
#     606         reset=first_call,
#     607     )
#     609     n_samples, n_features = X.shape
#     611     _check_partial_fit_first_call(self, classes)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1051         array = xp.astype(array, dtype, copy=False)
#    1052     else:
# -> 1053         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1054 except ComplexWarning as complex_warning:
#    1055     raise ValueError(
#    1056         "Complex data not supported\n{}\n".format(array)
#    1057     ) from complex_warning
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_array_api.py:757, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     755     array = numpy.array(array, order=order, dtype=dtype)
#     756 else:
# --> 757     array = numpy.asarray(array, order=order, dtype=dtype)
#     759 # At this point array is a NumPy ndarray. We convert it to an array
#     760 # container that is consistent with the input's namespace.
#     761 return xp.asarray(array)
#
# ValueError: could not convert string to float: 'State-gov'

# %%
# For Adaline (which uses GD), SGDClassifier with 'hinge' loss is a good proxy, as it's a linear classifier with regularization
sk_ada = SGDClassifier(loss='perceptron', eta0=0.0001, learning_rate='constant', max_iter=15, random_state=42)
sk_ada.fit(X_train, y_train)
sk_y_pred_ada = sk_ada.predict(X_test)
print(f"Scikit-learn Adaline (SGDClassifier) accuracy: {accuracy_score(y_test, sk_y_pred_ada):.4f}")
